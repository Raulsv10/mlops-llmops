# %% [markdown]
# # Práctica Final: Clasificación con Scikit-learn y MLflow
#
# En esta práctica, utilizarás un conjunto de datos de Scikit-learn (podeís usar el mismo que en el notebook de Intro MLFlow) para entrenar un modelo de clasificación.
#
# Pasos a seguir:
#
#     Exploración de Datos: Analiza el conjunto de datos proporcionado para comprender su estructura y contenido.
#
#     Preprocesamiento de Texto: Realiza tareas de preprocesamiento de texto, como tokenización y vectorización, para preparar los datos para el modelado.
#
#     Entrenamiento del Modelo: Utiliza algoritmos de clasificación de Scikit-learn para entrenar un modelo con los datos preprocesados.
#
#     Evaluación del Modelo: Evalúa el rendimiento del modelo utilizando métricas de evaluación estándar como precisión y recall.
#
#     Registro de Métricas con MLflow: Utiliza MLflow para registrar métricas y hiperparámetros durante el entrenamiento, facilitando la gestión y comparación de experimentos.
#
#
# Nota: Dado que no voy a poder tener acceso a vuestros logs de MLFlow añadirme las imagenes de la interfaz de MLFlow en el notebook

# %%
# %pip install scikit-learn mlflow pandas
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (1.7.2)
# Requirement already satisfied: mlflow in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (3.9.0)
# Requirement already satisfied: pandas in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: skops<1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: waitress<4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.82.0)
# Requirement already satisfied: fastapi<1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in c:\users\hades\appdata\roaming\python\python310\site-packages (from mlflow-skinny==3.9.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.0)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hades\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: Mako in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (2.3.0)
# Requirement already satisfied: colorama in c:\users\hades\appdata\roaming\python\python310\site-packages (from click<9,>=7.0->mlflow-skinny==3.9.0->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: pywin32>=304 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\hades\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.6.2)
# Requirement already satisfied: prettytable>=3.9 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hades\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\hades\anaconda3\envs\deepcpu\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: wcwidth in c:\users\hades\appdata\roaming\python\python310\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import fetch_20newsgroups
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score
import mlflow
import mlflow.sklearn

# %%
# carga de datos
data = fetch_20newsgroups(subset="all", remove=("headers", "footers", "quotes"))

texts = data.data
labels = data.target
label_names = data.target_names

print("Total de documentos:", len(texts))
print("Total de clases:", len(label_names))
print("Ejemplo de clases:", label_names[:5])

lengths = [len(t) for t in texts]
print("Longitud media (chars):", sum(lengths) / len(lengths))

# distribuir la clases
counts = Counter(labels)
print("Top 5 clases más frecuentes:", counts.most_common(5))

print(texts[0][:250])
# Out:
# Total de documentos: 18846
# Total de clases: 20
# Ejemplo de clases: ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware']
# Longitud media (chars): 1169.667515653189
# Top 5 clases más frecuentes: [(np.int64(10), 999), (np.int64(15), 997), (np.int64(8), 996), (np.int64(9), 994), (np.int64(11), 991)]
#
#
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' re

# %%
# Train y Test
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=42, stratify=labels )

print("Train tamaño:", len(X_train))
print("Test tamaño:", len(X_test))

# 2) Vectorizar
vectorizer = TfidfVectorizer( lowercase=True, stop_words="english", max_features=10000  )

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("train:", X_train_tfidf.shape)
print("Test:", X_test_tfidf.shape)
# Out:
# Train tamaño: 15076
# Test tamaño: 3770
# train: (15076, 10000)
# Test: (3770, 10000)

# %%
# local
#mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("text_classification_practica")

# Se define modelo
model = LogisticRegression(max_iter=1000, n_jobs=-1)

# Entrenamiento
with mlflow.start_run():
    
    mlflow.log_param("model_type", "LogisticRegression")
    mlflow.log_param("max_iter", 1000)
    mlflow.log_param("vectorizer", "TF-IDF")
    
    model.fit(X_train_tfidf, y_train)
    
    y_pred = model.predict(X_test_tfidf)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average="weighted")
    recall = recall_score(y_test, y_pred, average="weighted")
    
    mlflow.log_metric("accuracy", accuracy)
    mlflow.log_metric("precision", precision)
    mlflow.log_metric("recall", recall)
    
    mlflow.sklearn.log_model(model, "model")
    
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
# Out:
# 2026/01/31 15:37:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# c:\Users\hades\anaconda3\envs\deepcpu\lib\site-packages\mlflow\models\model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# Accuracy: 0.73342175066313
# Precision: 0.7418087028737151
# Recall: 0.73342175066313

# %%
## Observaciones
## Se utilizo MlFLOW para entrenamiento y registro de experimentos, almacenamiento de parametros, metricoas y el entrenamiento del modelo. las ejecucioenes quedan registradas en el mlflow como run independientes, permitiendo comparar resultados y con la  reproducibilidad del modelo.

# %% [markdown]
# ## Generar .py de funciones y main con al menos dos argumentos de entrada.

# %% [markdown]
# ## Práctica parte FastAPI

# %% [markdown]
# ### Para esta parte de la práctica teneis que generar un script con al menos 5 modulos app.get y dos de ellos tienen que ser pipelines de HF.
#
# ### Parte de la practica se tendra que entregar en capturas de pantalla. Las capturas de pantalla a adjuntas son las siguientes.
#
# ### 1. Captura de la pantalla docs con al menos 5 modulos.
# ### 2. Captura de cada una de los modulos con la respuesta dentro de docs.
# ### 3. Captura de cada uno de los modulos en la llamada https.
# ### 4. Todo el codigo usado durante el proceso. Notebooks y scripts.
#
# ### Opcional
#
# ### 5. Despliegue del script en GCP Cloud Run

# %%
# Se utilizo FastAPI para desplegar un servicio web que expone endpoints para clasificar texto utilizando modelos de HuggingFace, se comparten capturas de pantalla en el Word Adjunto.

# %%
# Quedo pendiente de subirlo a GCP
